# %% [markdown]
# ### To Install Seaborn
#
# pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# %%
tips = pd.read_csv('tips_v1.csv')
tips.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    percent_tip_wrt_total_bill
# 0                        5.94
# 1                       16.05
# 2                       16.66
# 3                       13.98
# 4                       14.68

# %%
'Kids','Women','Men','Seniors'
# Out:
#                             total_bill       tip      size  \
# total_bill                    1.000000  0.675734  0.598315
# tip                           0.675734  1.000000  0.489299
# size                          0.598315  0.489299  1.000000
# percent_tip_wrt_total_bill   -0.338629  0.342361 -0.142844
#
#                             percent_tip_wrt_total_bill
# total_bill                                   -0.338629
# tip                                           0.342361
# size                                         -0.142844
# percent_tip_wrt_total_bill                    1.000000

# %%
# corr_v1=tips[['total_bill', 'tip']]

# %%
# tips[['total_bill', 'tip', 'size']].sample(20)

# %%
fig = plt.figure(figsize = (6,3))
# sns.heatmap(tips.corr(numeric_only=True), annot = True)
sns.heatmap(tips.corr(), annot = True)

# sns.heatmap(tips[['total_bill', 'tip', 'size']].sample(20).corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### countplot
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(data = tips, x = 'day' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# ## boxplot and violinplot

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data = tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
sns.boxplot(data = tips, x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(data = tips, x = 'day', y = "total_bill", hue = 'day', palette = 'pastel')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data = tips, x = "gender", y = "total_bill", palette = 'pastel', hue = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='total_bill'>

# %%
sns.boxplot(x = "gender", y = "total_bill", 
            hue = "day",
            data = tips,
            palette = "pastel", gap = 0.2)

plt.legend(loc = 'best')

# %% [markdown]
# ### violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %% [markdown]
# ![VP.png](attachment:VP.png)

# %%
plt.violinplot(tips['total_bill'])
plt.show()

# %%
sns.violinplot(tips['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips , palette = 'coolwarm' , hue = 'day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue = 'gender',  palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue = 'gender',  palette = 'coolwarm' , split = True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## **Bubble Plot**

# %%
tips.head(1)
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
plt.figure(figsize = (10,5))

sns.scatterplot(data = tips,
                x = "tip", y = "total_bill", size = "size", hue = "gender",
                alpha = 0.5, legend = True, sizes = (2, 200))

plt.title("Bubble Chart");

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips , hue = 'smoker');
