# %%
from datetime import timedelta
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
#import datetime as dt
aus_sales_df = pd.read_csv('AusApparalSales4thQrt2020.csv')
min_max_scaler = MinMaxScaler()
std_scaler = StandardScaler()
# Data wrangling
print("is nan value count" ,  aus_sales_df.isna().sum().sum())
print("describe data", aus_sales_df.describe())
print("info data", aus_sales_df.info())
print("shape of sales data", aus_sales_df.shape)
print("columns of sales data", aus_sales_df.columns)
print("data types of sales data", aus_sales_df.dtypes)

# Function to get quarter from month
def get_quarter(month):
    if month in ['January', 'February', 'March']:
        return 'Q1'
    elif month in ['April', 'May', 'June']:
        return 'Q2'
    elif month in ['July', 'August', 'September']:
        return 'Q3'
    elif month in ['October', 'November', 'December']:
        return 'Q4'
    else:
        return None

# Date Feature Extraction
aus_sales_df['formatted_date'] = pd.to_datetime(aus_sales_df['Date'])
aus_sales_df['day'] = aus_sales_df['formatted_date'].dt.day_name()
aus_sales_df['month'] = aus_sales_df['formatted_date'].dt.month_name()
aus_sales_df['year'] = aus_sales_df['formatted_date'].dt.year
aus_sales_df['week'] = (aus_sales_df['formatted_date'].dt.day - 1) // 7 + 1

# Quarter Extraction
aus_sales_df['quarter'] =aus_sales_df['formatted_date'].dt.month_name().apply(get_quarter)
# Min-Max Scaling
aus_sales_df['unit_scaled'] = min_max_scaler.fit_transform(aus_sales_df[['Unit']])
# Standard Scaling
aus_sales_df['sales_standard_scaled'] = std_scaler.fit_transform(aus_sales_df[['Sales']])




aus_sales_df['Week_Start'] = aus_sales_df['formatted_date'].dt.to_period('W-MON').dt.start_time
aus_sales_df['Week_End'] = aus_sales_df['Week_Start'] + timedelta(days=6)
aus_sales_df['Week_Label'] = aus_sales_df['Week_Start'].dt.strftime('%Y-%m-%d') + '--To--' + aus_sales_df['Week_End'].dt.strftime('%Y-%m-%d')

aus_sales_df.head()
# Out:
# is nan value count 0
# describe data               Unit          Sales
# count  7560.000000    7560.000000
# mean     18.005423   45013.558201
# std      12.901403   32253.506944
# min       2.000000    5000.000000
# 25%       8.000000   20000.000000
# 50%      14.000000   35000.000000
# 75%      26.000000   65000.000000
# max      65.000000  162500.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7560 non-null   object
#  1   Time    7560 non-null   object
#  2   State   7560 non-null   object
#  3   Group   7560 non-null   object
#  4   Unit    7560 non-null   int64
#  5   Sales   7560 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 354.5+ KB
# info data None
# shape of sales data (7560, 6)
# columns of sales data Index(['Date', 'Time', 'State', 'Group', 'Unit', 'Sales'], dtype='object')
# data types of sales data Date     object
# Time     object
# State    object
# Group    object
# Unit      int64
# Sales     int64
# dtype: object
#          Date        Time State     Group  Unit  Sales formatted_date  \
# 0  1-Oct-2020     Morning    WA      Kids     8  20000     2020-10-01
# 1  1-Oct-2020     Morning    WA       Men     8  20000     2020-10-01
# 2  1-Oct-2020     Morning    WA     Women     4  10000     2020-10-01
# 3  1-Oct-2020     Morning    WA   Seniors    15  37500     2020-10-01
# 4  1-Oct-2020   Afternoon    WA      Kids     3   7500     2020-10-01
#
#         day    month  year  week quarter  unit_scaled  sales_standard_scaled  \
# 0  Thursday  October  2020     1      Q4     0.095238              -0.775581
# 1  Thursday  October  2020     1      Q4     0.095238              -0.775581
# 2  Thursday  October  2020     1      Q4     0.031746              -1.085645
# 3  Thursday  October  2020     1      Q4     0.206349              -0.232969
# 4  Thursday  October  2020     1      Q4     0.015873              -1.163162
#
#   Week_Start   Week_End                  Week_Label
# 0 2020-09-29 2020-10-05  2020-09-29--To--2020-10-05
# 1 2020-09-29 2020-10-05  2020-09-29--To--2020-10-05
# 2 2020-09-29 2020-10-05  2020-09-29--To--2020-10-05
# 3 2020-09-29 2020-10-05  2020-09-29--To--2020-10-05
# 4 2020-09-29 2020-10-05  2020-09-29--To--2020-10-05

# %% [markdown]
# ## # Calculate descriptive statistics for Sales and Unit columns

# %%
aus_sales_df[['Unit','Sales']].mean()
aus_sales_df[['Unit','Sales']].mode()
aus_sales_df[['Unit','Sales']].std()
aus_sales_df[['Unit','Sales']].median()
# Out:
# Unit        14.0
# Sales    35000.0
# dtype: float64

# %% [markdown]
# ## GROUP BY

# %%
# Group by 'State' and calculate total sales
sales_by_state = aus_sales_df.groupby(['State','Group'])['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)
sales_by_state.head()
# State and Group wise sales for Kids category
kids_df = aus_sales_df[ aus_sales_df['Group'] == ' Kids' ]
kids_df.groupby(['State'])[['Unit','Sales']].sum().reset_index()

kids_df.head()
# Out:
#           Date        Time State  Group  Unit  Sales formatted_date       day  \
# 0   1-Oct-2020     Morning    WA   Kids     8  20000     2020-10-01  Thursday
# 4   1-Oct-2020   Afternoon    WA   Kids     3   7500     2020-10-01  Thursday
# 8   1-Oct-2020     Evening    WA   Kids    15  37500     2020-10-01  Thursday
# 12  1-Oct-2020     Morning    NT   Kids    13  32500     2020-10-01  Thursday
# 16  1-Oct-2020   Afternoon    NT   Kids    13  32500     2020-10-01  Thursday
#
#       month  year  week quarter  unit_scaled  sales_standard_scaled
# 0   October  2020    40      Q4     0.095238              -0.775581
# 4   October  2020    40      Q4     0.015873              -1.163162
# 8   October  2020    40      Q4     0.206349              -0.232969
# 12  October  2020    40      Q4     0.174603              -0.388001
# 16  October  2020    40      Q4     0.174603              -0.388001

# %%
# State and Group wise sales for all categories
print("========================= State and Group wise sum =================")
state_group_sum = aus_sales_df.groupby(['State','Group'])[['Unit','Sales']].sum().reset_index()
print(state_group_sum)
print("========================= State and Group wise mean =================")
# State and Group wise mean, std, median
state_group_mean = aus_sales_df.groupby(['State','Group'])[['Unit','Sales']].mean().reset_index()
print(state_group_mean)
print("========================= State and Group wise std =================")
state_group_std = aus_sales_df.groupby(['State','Group'])[['Unit','Sales']].std().reset_index()
print(state_group_std)
print("========================= State and Group wise median =================")
state_group_median = aus_sales_df.groupby(['State','Group'])[['Unit','Sales']].median().reset_index()
print(state_group_median)
# Out:
#    State     Group   Unit     Sales
# 0    NSW      Kids   7435  18587500
# 1    NSW       Men   7609  19022500
# 2    NSW   Seniors   7275  18187500
# 3    NSW     Women   7669  19172500
# 4     NT      Kids   2280   5700000
# 5     NT       Men   2305   5762500
# 6     NT   Seniors   2186   5465000
# 7     NT     Women   2261   5652500
# 8    QLD      Kids   3404   8510000
# 9    QLD       Men   3357   8392500
# 10   QLD   Seniors   3276   8190000
# 11   QLD     Women   3330   8325000
# 12    SA      Kids   5806  14515000
# 13    SA       Men   5862  14655000
# 14    SA   Seniors   5887  14717500
# 15    SA     Women   5988  14970000
# 16   TAS      Kids   2310   5775000
# 17   TAS       Men   2303   5757500
# 18   TAS   Seniors   2260   5650000
# 19   TAS     Women   2231   5577500
# 20   VIC      Kids  10544  26360000
# 21   VIC       Men  10563  26407500
# 22   VIC   Seniors  10526  26315000
# 23   VIC     Women  10593  26482500
# 24    WA      Kids   2250   5625000
# 25    WA       Men   2301   5752500
# 26    WA   Seniors   2205   5512500
# 27    WA     Women   2105   5262500
# =========================
#    State     Group       Unit         Sales
# 0    NSW      Kids  27.537037  68842.592593
# 1    NSW       Men  28.181481  70453.703704
# 2    NSW   Seniors  26.944444  67361.111111
# 3    NSW     Women  28.403704  71009.259259
# 4     NT      Kids   8.444444  21111.111111
# 5     NT       Men   8.537037  21342.592593
# 6     NT   Seniors   8.096296  20240.740741
# 7     NT     Women   8.374074  20935.185185
# 8    QLD      Kids  12.607407  31518.518519
# 9    QLD       Men  12.433333  31083.333333
# 10   QLD   Seniors  12.133333  30333.333333
# 11   QLD     Women  12.333333  30833.333333
# 12    SA      Kids  21.503704  53759.259259
# 13    SA       Men  21.711111  54277.777778
# 14    SA   Seniors  21.803704  54509.259259
# 15    SA     Women  22.177778  55444.444444
# 16   TAS      Kids   8.555556  21388.888889
# 17   TAS       Men   8.529630  21324.074074
# 18   TAS   Seniors   8.370370  20925.925926
# 19   TAS     Women   8.262963  20657.407407
# 20   VIC      Kids  39.051852  97629.629630
# 21   VIC       Men  39.122222  97805.555556
# 22   VIC   Seniors  38.985185  97462.962963
# 23   VIC     Women  39.233333  98083.333333
# 24    WA      Kids   8.333333  20833.333333
# 25    WA       Men   8.522222  21305.555556
# 26    WA   Seniors   8.166667  20416.666667
# 27    WA     Women   7.796296  19490.740741
# =========================
#    State     Group       Unit         Sales
# 0    NSW      Kids   8.032261  20080.651527
# 1    NSW       Men   8.124978  20312.445257
# 2    NSW   Seniors   8.376850  20942.126100
# 3    NSW     Women   8.428355  21070.886454
# 4     NT      Kids   3.520871   8802.176705
# 5     NT       Men   3.703274   9258.184400
# 6     NT   Seniors   3.576824   8942.058812
# 7     NT     Women   3.540115   8850.286312
# 8    QLD      Kids   5.345458  13363.645325
# 9    QLD       Men   5.441920  13604.801115
# 10   QLD   Seniors   5.243938  13109.844764
# 11   QLD     Women   5.336972  13342.430292
# 12    SA      Kids   7.118095  17795.236806
# 13    SA       Men   6.937712  17344.279739
# 14    SA   Seniors   6.862049  17155.122882
# 15    SA     Women   7.038784  17596.960986
# 16   TAS      Kids   3.512414   8781.034537
# 17   TAS       Men   3.623171   9057.928712
# 18   TAS   Seniors   3.511512   8778.780288
# 19   TAS     Women   3.797049   9492.622881
# 20   VIC      Kids  10.339816  25849.540558
# 21   VIC       Men  10.591251  26478.127444
# 22   VIC   Seniors  11.017718  27544.295494
# 23   VIC     Women  10.692439  26731.097619
# 24    WA      Kids   3.648089   9120.221415
# 25    WA       Men   3.720418   9301.045564
# 26    WA   Seniors   3.703460   9258.649126
# 27    WA     Women   3.680450   9201.124639
# =========================
#    State     Group  Unit     Sales
# 0    NSW      Kids  28.0   70000.0
# 1    NSW       Men  29.0   72500.0
# 2    NSW   Seniors  26.0   65000.0
# 3    NSW     Women  29.0   72500.0
# 4     NT      Kids   8.0   20000.0
# 5     NT       Men   8.0   20000.0
# 6     NT   Seniors   8.0   20000.0
# 7     NT     Women   8.0   20000.0
# 8    QLD      Kids  12.0   30000.0
# 9    QLD       Men  12.0   30000.0
# 10   QLD   Seniors  11.5   28750.0
# 11   QLD     Women  12.0   30000.0
# 12    SA      Kids  21.0   52500.0
# 13    SA       Men  21.0   52500.0
# 14    SA   Seniors  21.0   52500.0
# 15    SA     Women  22.0   55000.0
# 16   TAS      Kids   8.0   20000.0
# 17   TAS       Men   8.0   20000.0
# 18   TAS   Seniors   8.5   21250.0
# 19   TAS     Women   8.0   20000.0
# 20   VIC      Kids  40.0  100000.0
# 21   VIC       Men  38.5   96250.0
# 22   VIC   Seniors  37.0   92500.0
# 23   VIC     Women  38.0   95000.0
# 24    WA      Kids   8.0   20000.0
# 25    WA       Men   8.0   20000.0
# 26    WA   Seniors   8.0   20000.0
# 27    WA     Women   7.0   17500.0

# %% [markdown]
# ## Find the Group with highest and lowest total Sales

# %%
# Initialize an empty dictionary to store group sums
group_sales_sum = {}
unique_groups = aus_sales_df['Group'].unique()
type(unique_groups)
# Iterate over each group, filter the DataFrame, and sum Sales
for group in unique_groups:
    group_df = aus_sales_df[aus_sales_df['Group'] == group]
    total_sales = int(group_df['Sales'].sum())
    group_sales_sum[group] = total_sales

#print(group_sales_sum)

sorted_group_sales = sorted(group_sales_sum.items(), key=lambda item: item[1], reverse=True)
highest_group, highest_sales = sorted_group_sales[0]
lowest_group, lowest_sales = sorted_group_sales[-1]

print(f"Highest Sales Group: {highest_group} with Sales: {highest_sales}")
print(f"Lowest Sales Group: {lowest_group} with Sales: {lowest_sales}")
# Out:
# Highest Sales Group:  Men with Sales: 85750000
# Lowest Sales Group:  Seniors with Sales: 84037500

# %% [markdown]
# Weekly Sales Report

# %%
weekly_report = aus_sales_df.groupby(['Week_Label']).agg({
    'Sales': 'sum',
    'Unit': 'sum'
}).reset_index().sort_values(by=['Sales'], ascending=True)

print(weekly_report)

weekly_report_state_group = aus_sales_df.groupby(['Week_Label','State','Group']).agg({
    'Sales': 'sum',
    'Unit': 'sum'
}).reset_index().sort_values(by=['Sales'], ascending=True)

print(weekly_report_state_group)
# Out:
#                 Week_Label     Sales   Unit
# 13  2020-12-29To2021-01-04   9197500   3679
# 0   2020-09-29To2020-10-05  18907500   7563
# 4   2020-10-27To2020-11-02  20797500   8319
# 5   2020-11-03To2020-11-09  21065000   8426
# 7   2020-11-17To2020-11-23  21187500   8475
# 6   2020-11-10To2020-11-16  21242500   8497
# 8   2020-11-24To2020-11-30  21442500   8577
# 3   2020-10-20To2020-10-26  26590000  10636
# 2   2020-10-13To2020-10-19  26805000  10722
# 1   2020-10-06To2020-10-12  26935000  10774
# 9   2020-12-01To2020-12-07  30817500  12327
# 11  2020-12-15To2020-12-21  31247500  12499
# 12  2020-12-22To2020-12-28  32007500  12803
# 10  2020-12-08To2020-12-14  32060000  12824
#                  Week_Label State     Group    Sales  Unit
# 369  2020-12-29To2021-01-04    NT       Men   115000    46
# 371  2020-12-29To2021-01-04    NT     Women   125000    50
# 380  2020-12-29To2021-01-04   TAS      Kids   147500    59
# 389  2020-12-29To2021-01-04    WA       Men   150000    60
# 388  2020-12-29To2021-01-04    WA      Kids   160000    64
# ..                      ...   ...       ...      ...   ...
# 357  2020-12-22To2020-12-28   VIC       Men  2532500  1013
# 329  2020-12-15To2020-12-21   VIC       Men  2537500  1015
# 358  2020-12-22To2020-12-28   VIC   Seniors  2610000  1044
# 359  2020-12-22To2020-12-28   VIC     Women  2630000  1052
# 302  2020-12-08To2020-12-14   VIC   Seniors  2635000  1054
#
# [392 rows x 5 columns]

# %% [markdown]
# Monthly Sales Report

# %%
monthly_report = aus_sales_df.groupby(['month']).agg({
    'Sales': 'sum',
    'Unit': 'sum'
}).reset_index().sort_values(by=['Sales'], ascending=True)

print(monthly_report)


mens_df = aus_sales_df[aus_sales_df['Group'] == ' Men' ]
monthly_report_state_group = mens_df.groupby(['month','State','Group']).agg({
    'Sales': 'sum',
    'Unit': 'sum'
}).reset_index().sort_values(by=['Sales'], ascending=True)



print(monthly_report_state_group)
# Out:
#       month      Sales   Unit
# 1  November   90682500  36273
# 2   October  114290000  45716
# 0  December  135330000  54132
#        month State Group     Sales  Unit
# 8   November    NT   Men   1280000   512
# 13  November    WA   Men   1332500   533
# 11  November   TAS   Men   1350000   540
# 9   November   QLD   Men   1982500   793
# 18   October   TAS   Men   2035000   814
# 15   October    NT   Men   2122500   849
# 20   October    WA   Men   2127500   851
# 6   December    WA   Men   2292500   917
# 1   December    NT   Men   2360000   944
# 4   December   TAS   Men   2372500   949
# 16   October   QLD   Men   2855000  1142
# 2   December   QLD   Men   3555000  1422
# 10  November    SA   Men   3910000  1564
# 17   October    SA   Men   5087500  2035
# 7   November   NSW   Men   5490000  2196
# 3   December    SA   Men   5657500  2263
# 14   October   NSW   Men   6270000  2508
# 0   December   NSW   Men   7262500  2905
# 12  November   VIC   Men   7270000  2908
# 19   October   VIC   Men   8387500  3355
# 5   December   VIC   Men  10750000  4300

# %% [markdown]
# Yearly Sales Report

# %%
print("======================== Yearly sales ======================")

yearly_report = aus_sales_df.groupby(['year']).agg({
    'Sales': 'sum',
    'Unit': 'sum'
}).reset_index().sort_values(by=['Sales'], ascending=True)

print(yearly_report)


print("================= Yearly State and Group wise Sales using pivot ================")
aus_sales_df.pivot_table(index = 'year' , columns = 'Group' , values = 'Sales' , aggfunc = 'sum')
# Out:
# ======================== Yearly sales ======================
#    year      Sales    Unit
# 0  2020  340302500  136121
# ================= Yearly State and Group wise Sales using pivot ================
# Group      Kids       Men   Seniors     Women
# year
# 2020   85072500  85750000  84037500  85442500

# %%
state_grouped_df = aus_sales_df.groupby(['State', 'Group','Time'])[['Unit', 'Sales']].sum().reset_index()
state_grouped_df.groupby(['State'])[['Sales']].sum().reset_index().sort_values(by='Sales')

time_group_df =  aus_sales_df.groupby(['Time'])[['Sales']].sum()
time_group_df.reset_index().sort_values(by='Sales')



aus_sales_df.pivot_table(index = 'Time' , columns = 'Group' , values = 'Sales' , aggfunc = 'sum')
#aus_sales_df['Time'].unique()

#kids_df = aus_sales_df[ (aus_sales_df['Group'] == ' Kids') & (aus_sales_df['Time'] == ' Afternoon') ]
#kids_df.groupby(['State'])[['Unit','Sales']].sum().reset_index()
#kids_df['Sales'].sum()

aus_sales_df.head()

mode_value = aus_sales_df['Sales'].mean()
print(mode_value)
# Out:
# 45013.5582010582

# %%
monthly_report = aus_sales_df.groupby(['year', 'month']).agg({
    'Sales': 'sum',
    'Unit': 'sum'
}).reset_index().sort_values(by=['Sales'], ascending=False)

monthly_report
# Out:
#    year     month      Sales   Unit
# 0  2020  December  135330000  54132
# 2  2020   October  114290000  45716
# 1  2020  November   90682500  36273

# %%
# Visualization using Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# prepare data
df = aus_sales_df.copy()
df['Group'] = df['Group'].astype(str).str.strip().str.title()   # normalize group names
agg = df.groupby(['State','Group'])['Sales'].sum().reset_index()

# optional: limit to main demographics present in your data
wanted = ['Kids','Women','Men','Seniors']
agg = agg[agg['Group'].isin(wanted)]

# Pivot for heatmap / stacked plots
pivot = agg.pivot(index='State', columns='Group', values='Sales').fillna(0)

# 1) Grouped barplot (one plot, hue by Group)
plt.figure(figsize=(14,6))
sns.barplot(data=agg, x='State', y='Sales', hue='Group', dodge=True)
plt.xticks(rotation=45)
plt.title('State-wise Sales by Group (Grouped Bar)')
plt.tight_layout()
plt.show()

# 2) Heatmap (states vs groups)
plt.figure(figsize=(10,8))
sns.heatmap(pivot, annot=True, fmt='.0f', cmap='Blues')
plt.title('Heatmap: Sales by State and Group')
plt.tight_layout()
plt.show()

# python
# create faceted bar plots and rotate x labels without triggering the warning
g = sns.catplot(data=agg, x='State', y='Sales', col='Group', kind='bar',
                col_wrap=2, height=4, sharey=False)

for ax in g.axes.flatten():
    ax.tick_params(axis='x', rotation=45)   # safe rotation, avoids set_xticklabels warning

g.fig.suptitle('Per-Group State-wise Sales', y=1.02)
plt.tight_layout()
plt.show()

# %%
df = aus_sales_df.copy()

sns.boxplot(x = "Group", y = "Sales",
            hue = "State",
            data = df,
            palette = "pastel")
# Out:
# <Axes: xlabel='Group', ylabel='Sales'>

# %%
sns.boxplot(x = "State", y = "Sales",
            hue = "Group",
            data = df,
            palette = "pastel", width=0.6 ,dodge=True )
# Out:
# <Axes: xlabel='State', ylabel='Sales'>

# %%
sales_by_time = aus_sales_df.groupby("Time")["Sales"].sum().reset_index()
print(sales_by_time)
peak = sales_by_time.loc[sales_by_time["Sales"].idxmax()]
off_peak = sales_by_time.loc[sales_by_time["Sales"].idxmin()]
print(f"Peak Sales Time: {peak['Time']} with Sales: {peak['Sales']}")
print(f"Off-Peak Sales Time: {off_peak['Time']} with Sales: {off_peak['Sales']}")
# Out:
#          Time      Sales
# 0   Afternoon  114007500
# 1     Evening  112087500
# 2     Morning  114207500
# Peak Sales Time:  Morning with Sales: 114207500
# Off-Peak Sales Time:  Evening with Sales: 112087500

# %%
order = ["Morning", "Afternoon", "Evening"]

plt.figure(figsize=(5,3))
sns.barplot(data=sales_by_time, x="Time", y="Sales")
plt.title("Total Sales by Time of Day")
plt.ylabel("Total Sales")
plt.xlabel("Time of Day")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.violinplot(data=df, x="Time", y="Sales")
plt.title("Sales Density for Peak vs Off-Peak")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 plt.figure(figsize=(6,6))
#       2 plt.pie(
# ----> 3     sales_by_time["Sales"],
#       4     labels=sales_by_time["Time"],
#       5     autopct="%1.1f%%"
#       6 )
#       7 plt.title("Sales Contribution by Time of Day")
#       8 plt.show()
#
# NameError: name 'sales_by_time' is not defined
