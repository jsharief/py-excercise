# %%
print('Hello from Purdue!')

# %% [markdown]
# # Hello from Purdue!

# %%
print (5 > 7)
print(5 > 3)

sent = "'This is a sample' sentence'"
print(sent)

number_1 = 5
number_2 = 10
# Before Assignment
print("id of number 1" , id(number_1))
print("id of number 2" , id(number_2))

# After Assignment
number_1 = number_2

print("id of number 1" , id(number_1))
print("id of number 2" , id(number_2))

z = number_1  + number_2
z
# Out:
# False
# True
# 'This is a sample' sentence'
# id of number 1 4340279728
# id of number 2 4340279888
# id of number 1 4340279888
# id of number 2 4340279888
# 20
