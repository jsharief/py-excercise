# %%
# %time
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.15 µs

# %%
def test(*args):
    print(args)
test(['apple'],2,"ter")
# Out:
# (['apple'], 2, 'ter')

# %%
### KW Args
def kwargs(**kwargs):
    print(kwargs)

# %%
lst = ['jammu','kashmir','pondy','malia',range]
rge = lst[4]
for x in rge(5):
    print(x)
#print(rge[0])
print(lst)
print ('kashmira'in lst)
print(lst[1:5:2])
print(lst[::-1])
print(lst[4])
t = tuple(lst)
print(t)
hash(t)
print(t)
# Out:
# 0
# 1
# 2
# 3
# 4
# ['jammu', 'kashmir', 'pondy', 'malia', <class 'range'>]
# False
# ['kashmir', 'malia']
# [<class 'range'>, 'malia', 'pondy', 'kashmir', 'jammu']
# <class 'range'>
# ('jammu', 'kashmir', 'pondy', 'malia', <class 'range'>)
# ('jammu', 'kashmir', 'pondy', 'malia', <class 'range'>)

# %% [markdown]
# :p

# %% [markdown]
# ## For

# %%
for x in enumerate(lst):
    print(type(x))

print(lst)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# [<class 'range'>, 'malia', 'pondy', 'kashmir', 'jammu']

# %%
def my_yielder(n):
    i = 0
    while i < n:
        yield i
        i += 1

result = my_yielder(5)
print(next(result))
print(next(result))
print(next(result))
print(next(result))
print(next(result))
print(next(result))
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[11], line 13
#      11 print(next(result))
#      12 print(next(result))
# ---> 13 print(next(result))
#
# StopIteration:
